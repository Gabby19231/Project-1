# %% [markdown]
# ## Observations and Insights

# %% [markdown]
# Observations:
# 1. Capomulin and Ramicane seem to be the most effective drugs out of the 4 analyzed. The mice on these drugs ended up with lower tumor volumes than those on the other 2 drugs.
#
# 2. If a mouse has a higher body weight, then those mice tend to have larger tumors (as measured by tumor volume).
#
# 3. Mouse weight is a good predictor of average tumor volume, because those two metrics seem to be highly correlated with a correlation coefficient of 0.95.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import numpy as np

# Study data files
path = "State_of_Texas.csv"
voter_path = "VoterClintonTrump.csv"

# Read the mouse data and the study results
texas = pd.read_csv(path)
texas = texas.drop(columns=['FIPS', 'area_name'])
# voter = pd.read_csv(voter_path)

# Display the data table for preview
texas.head()
# Out:
#    year age_group     total  total_male  total_female  nh_white_total  \
# 0  2010       ALL  25145561    12472280      12673281        11397345
# 1  2010       <18   6865824     3510249       3355575         2322661
# 2  2010     18-24   2572969     1321619       1251350          994473
# 3  2010     25-44   7071855     3544857       3526998         2934239
# 4  2010     45-64   6033027     2959891       3073136         3385907
#
#    nh_white_male  nh_white_female  nh_black_total  nh_black_male  \
# 0        5632646          5764699         2886825        1392410
# 1        1193025          1129636          810543         413374
# 2         506474           487999          323437         161755
# 3        1478661          1455578          841640         403524
# 4        1674984          1710923          692831         326935
#
#    nh_black_female  hispanic_total  hispanic_male  hispanic_female  \
# 0          1494415         9460921        4763753          4697168
# ...

# %%
# no breakdown by age
all_ages = texas[texas['age_group'] == 'ALL']
all_ages.head()
# Out:
#     year age_group     total  total_male  total_female  nh_white_total  \
# 0   2010       ALL  25145561    12472280      12673281        11397345
# 6   2011       ALL  25567291    12684177      12883114        11473189
# 12  2012       ALL  25996722    12899473      13097249        11548679
# 18  2013       ALL  26433242    13118331      13314911        11624174
# 24  2014       ALL  26876429    13340220      13536209        11699326
#
#     nh_white_male  nh_white_female  nh_black_total  nh_black_male  \
# 0         5632646          5764699         2886825        1392410
# 6         5672925          5800264         2948232        1422595
# 12        5712731          5835948         3011317        1453567
# 18        5752529          5871645         3075723        1485314
# 24        5791913          5907413         3141271        1517572
#
#     nh_black_female  hispanic_total  hispanic_male  hispanic_female  \
# 0           1494415         9460921        4763753          4697168
# ...

# %%
# only broken down by age, and nothing else
age = texas[['year','age_group','total']]

# remove rows where age_group = ALL
age_no_all = age[age['age_group'] != 'ALL']
age_no_all.head(10)
# Out:
#     year age_group    total
# 1   2010       <18  6865824
# 2   2010     18-24  2572969
# 3   2010     25-44  7071855
# 4   2010     45-64  6033027
# 5   2010       65+  2601886
# 7   2011       <18  6913506
# 8   2011     18-24  2627419
# 9   2011     25-44  7176079
# 10  2011     45-64  6166601
# 11  2011       65+  2683686

# %%
# Reformat to plottable data

age_df = pd.pivot_table(age_no_all, values = 'total', index = 'year', columns = 'age_group')
age_df.plot(title = 'Age Group Changes by Time')
plt.ylabel('# of People')
plt.show()

# %%
# Show ages as % of total population, instead of population totals. 
# Basically show if the age group is growing as a share of total population.


age_with_all = pd.pivot_table(age, values = 'total', index = 'year', columns = 'age_group')


age_with_all['18-24'] = age_with_all['18-24']/age_with_all['ALL']
age_with_all['25-44'] = age_with_all['25-44']/age_with_all['ALL']
age_with_all['45-64'] = age_with_all['45-64']/age_with_all['ALL']
age_with_all['65+'] = age_with_all['65+']/age_with_all['ALL']
age_with_all['<18'] = age_with_all['<18']/age_with_all['ALL']
age_with_all = age_with_all.drop(columns=['ALL'])

age_with_all.plot(title = 'Age Group as Proportion of Total Population by Time')
plt.ylabel('% of People')
plt.show()

# %%
# Plot demographic changes over time, all genders. 

all_ages.plot(kind = 'line', x = 'year', y = ['nh_white_total', 'nh_black_total','hispanic_total','nh_asian_total','nh_other_total'], title = 'Texas Population Change by Time')
plt.ylabel('# of People')
plt.show()

# %%
# Filter for year 2030.
proj_2030 = texas[texas['year']== 2030]
proj_2030 = proj_2030[proj_2030['age_group']=='ALL']
proj_2030
#proj_2030.set_index('age_group')
# Out:
#      year age_group     total  total_male  total_female  nh_white_total  \
# 120  2030       ALL  34894452    17341921      17552531        12774056
#
#      nh_white_male  nh_white_female  nh_black_total  nh_black_male  \
# 120        6345427          6428629         4322983        2102630
#
#      nh_black_female  hispanic_total  hispanic_male  hispanic_female  \
# 120          2220353        14452949        7236976          7215973
#
#      nh_asian_total  nh_asian_male  nh_asian_female  nh_other_total  \
# 120         2414778        1192698          1222080          929686
#
#      nh_other_male  nh_other_female
# 120         464190           465496

# %%
# Getting the duplicate mice by ID number that shows up for Mouse ID and Timepoint. 
duplicate_mice = df[df.duplicated(['Mouse ID', 'Timepoint'])]
duplicate_mice
# Out:
#     Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 909     g989     Propriva  Female          21          26          0
# 911     g989     Propriva  Female          21          26          5
# 913     g989     Propriva  Female          21          26         10
# 915     g989     Propriva  Female          21          26         15
# 917     g989     Propriva  Female          21          26         20
#
#      Tumor Volume (mm3)  Metastatic Sites
# 909           45.000000                 0
# 911           47.570392                 0
# 913           49.880528                 0
# 915           53.442020                 0
# 917           54.657650                 1

# %%
# Optional: Get all the data for the duplicate mouse ID. 
dup_mouse = duplicate_mice['Mouse ID'].unique()
#dup_mouse

dup_data = df.set_index('Mouse ID').loc[dup_mouse]
dup_data
# Out:
#          Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# Mouse ID
# g989         Propriva  Female          21          26          0
# g989         Propriva  Female          21          26          0
# g989         Propriva  Female          21          26          5
# g989         Propriva  Female          21          26          5
# g989         Propriva  Female          21          26         10
# g989         Propriva  Female          21          26         10
# g989         Propriva  Female          21          26         15
# g989         Propriva  Female          21          26         15
# g989         Propriva  Female          21          26         20
# g989         Propriva  Female          21          26         20
# g989         Propriva  Female          21          26         25
# g989         Propriva  Female          21          26         30
# g989         Propriva  Female          21          26         35
#
# ...

# %%
# Create a clean DataFrame by dropping the duplicate mouse by its ID.
df = df[df['Mouse ID'] != dup_mouse[0]]
df.head()
# Out:
#   Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0     k403     Ramicane  Male          21          16          0
# 1     k403     Ramicane  Male          21          16          5
# 2     k403     Ramicane  Male          21          16         10
# 3     k403     Ramicane  Male          21          16         15
# 4     k403     Ramicane  Male          21          16         20
#
#    Tumor Volume (mm3)  Metastatic Sites
# 0           45.000000                 0
# 1           38.825898                 0
# 2           35.014271                 1
# 3           34.223992                 1
# 4           32.997729                 1

# %%
# Checking the number of mice in the clean DataFrame.
clean_mouse_count = len(set(df['Mouse ID']))
clean_mouse_count
# Out:
# 248

# %% [markdown]
# ## Summary Statistics

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen

# Use groupby and summary statistical methods to calculate the following properties of each drug regimen: 
# mean, median, variance, standard deviation, and SEM of the tumor volume. 
# Assemble the resulting series into a single summary dataframe.

mean = df.groupby('Drug Regimen')['Tumor Volume (mm3)'].mean()
median = df.groupby('Drug Regimen')['Tumor Volume (mm3)'].median()
variance = df.groupby('Drug Regimen')['Tumor Volume (mm3)'].var()
std_dev = df.groupby('Drug Regimen')['Tumor Volume (mm3)'].std()
SEM = df.groupby('Drug Regimen')['Tumor Volume (mm3)'].sem()

# Create summary statistics DF
summary = pd.DataFrame({
                        "Mean Tumor Vol": mean,
                        "Median Tumor Vol": median,
                        "Variance of Tumor Vol": variance,
                        "Standard Deviation of Tumor Vol": std_dev,
                        "SEM of Tumor Vol": SEM })
summary
# Out:
#               Mean Tumor Vol  Median Tumor Vol  Variance of Tumor Vol  \
# Drug Regimen
# Capomulin          40.675741         41.557809              24.947764
# Ceftamin           52.591172         51.776157              39.290177
# Infubinol          52.884795         51.820584              43.128684
# Ketapril           55.235638         53.698743              68.553577
# Naftisol           54.331565         52.509285              66.173479
# Placebo            54.033581         52.288934              61.168083
# Propriva           52.320930         50.446266              43.852013
# Ramicane           40.216745         40.673236              23.486704
# Stelasyn           54.233149         52.431737              59.450562
# Zoniferol          53.236507         51.818479              48.533355
#
#               Standard Deviation of Tumor Vol  SEM of Tumor Vol
# Drug Regimen
# Capomulin                            4.994774          0.329346
# ...

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen

# Using the aggregation method, produce the same summary statistics in a single line
summary2 = df.groupby('Drug Regimen')['Tumor Volume (mm3)'].agg(['mean', 'median','var','std','sem'])
summary2
# Out:
#                    mean     median        var       std       sem
# Drug Regimen
# Capomulin     40.675741  41.557809  24.947764  4.994774  0.329346
# Ceftamin      52.591172  51.776157  39.290177  6.268188  0.469821
# Infubinol     52.884795  51.820584  43.128684  6.567243  0.492236
# Ketapril      55.235638  53.698743  68.553577  8.279709  0.603860
# Naftisol      54.331565  52.509285  66.173479  8.134708  0.596466
# Placebo       54.033581  52.288934  61.168083  7.821003  0.581331
# Propriva      52.320930  50.446266  43.852013  6.622085  0.544332
# Ramicane      40.216745  40.673236  23.486704  4.846308  0.320955
# Stelasyn      54.233149  52.431737  59.450562  7.710419  0.573111
# Zoniferol     53.236507  51.818479  48.533355  6.966589  0.516398

# %% [markdown]
# ## Bar and Pie Charts

# %%
# Generate a bar plot showing the total number of unique mice tested on each drug regimen using pandas.
unique = df.drop_duplicates(subset=['Mouse ID'])
unique_mouse_bar = unique['Drug Regimen'].value_counts().to_frame()

unique_mouse_bar.plot.bar(title="Number of Mice per Drug Regimen", legend=False)
plt.xlabel('Drug Regimen')
plt.ylabel('Unique Mouse Count')
plt.show()

# %%
# Generate a bar plot showing the total number of unique mice tested on each drug regimen using pyplot.

unique_mouse_bar_new = unique_mouse_bar.reset_index()
plt.figure(figsize=(10,3))
plt.bar(unique_mouse_bar_new['index'], unique_mouse_bar_new['Drug Regimen'])
plt.xlabel('Drug Regimen')
plt.ylabel('Unique Mouse Count')
plt.title('Number of Mice per Drug Regimen')
plt.show()

# %%
# Generate a pie plot showing the distribution of female versus male mice using pandas
mouse_sex = unique['Sex'].value_counts().to_frame()

mouse_sex.plot.pie(y='Sex',title="Distribution of Sex", legend=False)
plt.show()

# %%
# Generate a pie plot showing the distribution of female versus male mice using pyplot

mouse_sex_pyplt = mouse_sex.reset_index()
#plt.figure(figsize=(10,3))

plt.pie(mouse_sex_pyplt['Sex'], labels = mouse_sex_pyplt['index'])
plt.ylabel('Sex')
plt.title('Distribution of Sex')
plt.show()

# %% [markdown]
# ## Quartiles, Outliers and Boxplots

# %%
# Calculate the final tumor volume of each mouse across four of the treatment regimens:  
# Capomulin, Ramicane, Infubinol, and Ceftamin

# Start by getting the last (greatest) timepoint for each mouse
group = df.groupby(['Mouse ID'])['Timepoint'].max().to_frame()

# Merge this group df with the original dataframe to get the tumor volume at the last timepoint
final_tumor_vol = pd.merge(group,df,how='inner',left_on=['Mouse ID','Timepoint'],right_on=['Mouse ID','Timepoint'])
final_tumor_vol.head()
# Out:
#   Mouse ID  Timepoint Drug Regimen     Sex  Age_months  Weight (g)  \
# 0     a203         45    Infubinol  Female          20          23
# 1     a251         45    Infubinol  Female          21          25
# 2     a262         45      Placebo  Female          17          29
# 3     a275         45     Ceftamin  Female          20          28
# 4     a366         30     Stelasyn  Female          16          29
#
#    Tumor Volume (mm3)  Metastatic Sites
# 0           67.973419                 2
# 1           65.525743                 1
# 2           70.717621                 4
# 3           62.999356                 3
# 4           63.440686                 1

# %%
# Capomulin
capomulin = final_tumor_vol[final_tumor_vol['Drug Regimen'] == 'Capomulin']
capomulin_vol = capomulin['Tumor Volume (mm3)'].tolist()
capomulin_iqr = st.iqr(capomulin_vol)
#capomulin_quartile = np.percentile(capomulin_vol, [25, 50, 75])


# Ramicane
ramicane = final_tumor_vol[final_tumor_vol['Drug Regimen'] == 'Ramicane']
ramicane_vol = ramicane['Tumor Volume (mm3)'].tolist()
ramicane_iqr = st.iqr(ramicane_vol)
#ramicane_quartile = np.percentile(ramicane, [25, 50, 75])


# Infubinol
infubinol = final_tumor_vol[final_tumor_vol['Drug Regimen'] == 'Infubinol']
infubinol_vol = infubinol['Tumor Volume (mm3)'].tolist()
infubinol_iqr = st.iqr(infubinol_vol)
#infubinol_quartile = np.percentile(infubinol, [25, 50, 75])


# Ceftamin
ceftamin = final_tumor_vol[final_tumor_vol['Drug Regimen'] == 'Ceftamin']
ceftamin_vol = ceftamin['Tumor Volume (mm3)'].tolist()
ceftamin_iqr = st.iqr(ceftamin_vol)
#ceftamin_quartile = np.percentile(ceftamin, [25, 50, 75])

# %%
# Generate a box plot of the final tumor volume of each mouse across four regimens of interest

box = pd.DataFrame({
                        "Capomulin": capomulin_vol,
                        "Ramicane": ramicane_vol,
                        "Infubinol": infubinol_vol,
                        "Ceftamin": ceftamin_vol })
box

box.plot.box()
plt.xlabel('Drug Regimen')
plt.ylabel("Final Tumor Volume (mm3)")
plt.title('Boxplot of Final Tumor Vol by Drug Regimen')
plt.show()

# %% [markdown]
# ## Line and Scatter Plots

# %%
# Generate a line plot of tumor volume vs. time point for a mouse treated with Capomulin

capomulin_mouse = df[df['Mouse ID']=='s185']
capomulin_mouse.plot(kind = 'line', x = 'Timepoint', y = 'Tumor Volume (mm3)', title = 'Tumor Volume vs. Time for Mouse s185 on Capomulin')
plt.ylabel('Tumor Volume (mm3)')
plt.show()

# %%
# Generate a scatter plot of average tumor volume vs. mouse weight for the Capomulin regimen

capomulin_scatter = df[df['Drug Regimen']=='Capomulin']

capomulin_scatter = capomulin_scatter.groupby('Weight (g)')['Tumor Volume (mm3)'].mean().to_frame().reset_index()
#capomulin_scatter

capomulin_scatter.plot(kind = 'scatter', x = "Weight (g)", y = 'Tumor Volume (mm3)', title = 'Avg Tumor Volume vs. Mouse Weight for Capomulin')
plt.ylabel('Average Tumor Volume (mm3)')
plt.show()

# %% [markdown]
# ## Correlation and Regression

# %%
# Calculate the correlation coefficient and linear regression model 
# for mouse weight and average tumor volume for the Capomulin regimen

corr_coeff = round(st.pearsonr(capomulin_scatter['Weight (g)'],capomulin_scatter['Tumor Volume (mm3)'])[0],2)

vc_slope, vc_int, vc_r, vc_p, vc_std_err = st.linregress(capomulin_scatter['Weight (g)'],capomulin_scatter['Tumor Volume (mm3)'])
vc_fit = vc_slope * capomulin_scatter['Weight (g)'] + vc_int

capomulin_scatter.plot(kind = 'scatter', x = "Weight (g)", y = 'Tumor Volume (mm3)', title = 'Avg Tumor Volume vs. Mouse Weight for Capomulin')
plt.plot(capomulin_scatter['Weight (g)'],vc_fit,"--")
plt.ylabel('Average Tumor Volume (mm3)')
plt.show()
