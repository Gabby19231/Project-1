# %%
from matplotlib import pyplot as plt
from scipy import stats
import numpy as np
import pandas as pd

# %%
d = {'President': ['Harry Truman', 'Dwight Eisenhower', 'John Kennedy', 'Lyndon Johnson', 'Richard Nixon', 'Gerald Ford', 'Jimmy Carter', 'Ronald Reagan', 'George H.W. Bush', 'Bill Clinton', 'George W. Bush', 'Barack Obama'],
     'approval_rating': ['55.6%', '69.6%', '70.1%', '74.2%', '55.8%', '47.2%', '45.5%', '50.3%', '60.9%', '49.6%', '62.2%', '49.1%']}

approval_ratingDF = pd.DataFrame(data=d)
approval_ratingDF
# Out:
#             President approval_rating
# 0        Harry Truman           55.6%
# 1   Dwight Eisenhower           69.6%
# 2        John Kennedy           70.1%
# 3      Lyndon Johnson           74.2%
# 4       Richard Nixon           55.8%
# 5         Gerald Ford           47.2%
# 6        Jimmy Carter           45.5%
# 7       Ronald Reagan           50.3%
# 8    George H.W. Bush           60.9%
# 9        Bill Clinton           49.6%
# 10     George W. Bush           62.2%
# 11       Barack Obama           49.1%

# %%
d = {'President': ['Harry Truman', 'Dwight Eisenhower', 'John Kennedy', 'Lyndon Johnson', 'Richard Nixon', 'Gerald Ford', 'Jimmy Carter', 'Ronald Reagan', 'George H.W. Bush', 'Bill Clinton', 'George W. Bush', 'Barack Obama'],
     'Re_elected': ['Yes', 'Yes', 'N/A', 'Yes', 'Yes', 'No', 'No', 'Yes', 'No', 'Yes', 'Yes', 'Yes']}

re_electionDF = pd.DataFrame(data=d)
re_electionDF
# Out:
#             President Re_elected
# 0        Harry Truman        Yes
# 1   Dwight Eisenhower        Yes
# 2        John Kennedy        N/A
# 3      Lyndon Johnson        Yes
# 4       Richard Nixon        Yes
# 5         Gerald Ford         No
# 6        Jimmy Carter         No
# 7       Ronald Reagan        Yes
# 8    George H.W. Bush         No
# 9        Bill Clinton        Yes
# 10     George W. Bush        Yes
# 11       Barack Obama        Yes
