# %%
from matplotlib import pyplot as plt
from scipy import stats
import numpy as np
import pandas as pd

# %%
 # Load crime data set into pandas
states_data = pd.read_csv("/Users/marinaduarte/Documents/Project-1-Polling-Election-Data/0 YES 1976-2016-president.csv")
states_data.head()
# Out:
#    year    state state_po  state_fips  state_cen  state_ic        office  \
# 0  1976  Alabama       AL           1         63        41  US President
# 1  1976  Alabama       AL           1         63        41  US President
# 2  1976  Alabama       AL           1         63        41  US President
# 3  1976  Alabama       AL           1         63        41  US President
# 4  1976  Alabama       AL           1         63        41  US President
#
#                  candidate                       party  writein  \
# 0            Carter, Jimmy                    democrat    False
# 1             Ford, Gerald                  republican    False
# 2           Maddox, Lester  american independent party    False
# 3  Bubar, Benjamin ""Ben""                 prohibition    False
# 4                Hall, Gus         communist party use    False
#
#    candidatevotes  totalvotes   version  notes
# 0          659170     1182850  20171015    NaN
# ...

# %%
states_DR = states_data.loc[(states_data['party'] == 'democrat') | (states_data['party'] == 'republican')]
#states_R = states_data.loc[states_data['party'] == 'republican']
states_DR.head()
# Out:
#     year    state state_po  state_fips  state_cen  state_ic        office  \
# 0   1976  Alabama       AL           1         63        41  US President
# 1   1976  Alabama       AL           1         63        41  US President
# 7   1976   Alaska       AK           2         94        81  US President
# 8   1976   Alaska       AK           2         94        81  US President
# 11  1976  Arizona       AZ           4         86        61  US President
#
#         candidate       party  writein  candidatevotes  totalvotes   version  \
# 0   Carter, Jimmy    democrat    False          659170     1182850  20171015
# 1    Ford, Gerald  republican    False          504070     1182850  20171015
# 7    Ford, Gerald  republican    False           71555      123574  20171015
# 8   Carter, Jimmy    democrat    False           44058      123574  20171015
# 11   Ford, Gerald  republican    False          418642      742719  20171015
#
#     notes
# 0     NaN
# 1     NaN
# 7     NaN
# 8     NaN
# ...

# %%
N = 11
AlabamaDF = states_DR.loc[(states_DR['state'] == 'Alabama')]
labels = AlabamaDF['year']
x = np.arange(len(labels))  # the label locations
width = 0.35  # the width of the bars
democratDF = AlabamaDF.loc[AlabamaDF['party'] == 'democrat']
democrat_votes = democratDF['candidatevotes']
republicanDF = AlabamaDF.loc[AlabamaDF['party'] == 'republican']
republican_votes = republicanDF['candidatevotes']

ind = np.arange(N) 
width = 0.35       
plt.bar(ind, democrat_votes, width, label='Democrat', color='blue')
plt.bar(ind + width, republican_votes, width, label='Republican', color='red')

plt.ylabel('Year')
plt.title('Alabama votes by year')

plt.xticks(ind + width / 2, ('1976', '1980', '1984', '1988', '1992', '1996', '2000', '2004', '2008', '2012', '2016'))
plt.legend(loc='best')
plt.show()

N = 11
IllinoisDF = states_DR.loc[(states_DR['state'] == 'Illinois')]
labels = IllinoisDF['year']
x = np.arange(len(labels))  # the label locations
width = 0.35  # the width of the bars
democratDF = IllinoisDF.loc[IllinoisDF['party'] == 'democrat']
democrat_votes = democratDF['candidatevotes']
republicanDF = IllinoisDF.loc[IllinoisDF['party'] == 'republican']
republican_votes = republicanDF['candidatevotes']

ind = np.arange(N) 
width = 0.35       
plt.bar(ind, democrat_votes, width, label='Democrat', color='blue')
plt.bar(ind + width, republican_votes, width, label='Republican', color='red')

plt.ylabel('Year')
plt.title('Illinois votes by year')

plt.xticks(ind + width / 2, ('1976', '1980', '1984', '1988', '1992', '1996', '2000', '2004', '2008', '2012', '2016'))
plt.legend(loc='best')
plt.show()

N = 11
FloridaDF = states_DR.loc[(states_DR['state'] == 'Florida')]
labels = FloridaDF['year']
x = np.arange(len(labels))  # the label locations
width = 0.35  # the width of the bars
democratDF = FloridaDF.loc[FloridaDF['party'] == 'democrat']
democrat_votes = democratDF['candidatevotes']
republicanDF = FloridaDF.loc[FloridaDF['party'] == 'republican']
republican_votes = republicanDF['candidatevotes']

ind = np.arange(N) 
width = 0.35       
plt.bar(ind, democrat_votes, width, label='Democrat', color='blue')
plt.bar(ind + width, republican_votes, width, label='Republican', color='red')

plt.ylabel('Year')
plt.title('Florida votes by year')

plt.xticks(ind + width / 2, ('1976', '1980', '1984', '1988', '1992', '1996', '2000', '2004', '2008', '2012', '2016'))
plt.legend(loc='best')
plt.show()

N = 11
WisconsinDF = states_DR.loc[(states_DR['state'] == 'Wisconsin')]
labels = WisconsinDF['year']
x = np.arange(len(labels))  # the label locations
width = 0.35  # the width of the bars
democratDF = WisconsinDF.loc[WisconsinDF['party'] == 'democrat']
democrat_votes = democratDF['candidatevotes']
republicanDF = WisconsinDF.loc[WisconsinDF['party'] == 'republican']
republican_votes = republicanDF['candidatevotes']

ind = np.arange(N) 
width = 0.35       
plt.bar(ind, democrat_votes, width, label='Democrat', color='blue')
plt.bar(ind + width, republican_votes, width, label='Republican', color='red')

plt.ylabel('Year')
plt.title('Wisconsin votes by year')

plt.xticks(ind + width / 2, ('1976', '1980', '1984', '1988', '1992', '1996', '2000', '2004', '2008', '2012', '2016'))
plt.legend(loc='best')
plt.show()

N = 11
ColoradoDF = states_DR.loc[(states_DR['state'] == 'Colorado')]
labels = ColoradoDF['year']
x = np.arange(len(labels))  # the label locations
width = 0.35  # the width of the bars
democratDF = ColoradoDF.loc[ColoradoDF['party'] == 'democrat']
democrat_votes = democratDF['candidatevotes']
republicanDF = ColoradoDF.loc[ColoradoDF['party'] == 'republican']
republican_votes = republicanDF['candidatevotes']

ind = np.arange(N) 
width = 0.35       
plt.bar(ind, democrat_votes, width, label='Democrat', color='blue')
plt.bar(ind + width, republican_votes, width, label='Republican', color='red')

plt.ylabel('Year')
plt.title('Colorado votes by year')

plt.xticks(ind + width / 2, ('1976', '1980', '1984', '1988', '1992', '1996', '2000', '2004', '2008', '2012', '2016'))
plt.legend(loc='best')
plt.show()

# %%
d = {'year': ['1976', '1980', '1984', '1988', '1992', '1996', '2000', '2004', '2008', '2012', '2016'],
     'winner': ['Carter, Jimmy', 'Reagan, Ronald', 'Reagan, Ronald', 'Bush, George H. W.', 'Clinton, Bill', 'Clinton, Bill', 'Bush, George W.', 'Bush, George W.', 'Obama, Barack H.', 'Obama, Barack H.','Trump, Donald J.']}

winnerDF = pd.DataFrame(data=d)
winnerDF
# Out:
#     year              winner
# 0   1976       Carter, Jimmy
# 1   1980      Reagan, Ronald
# 2   1984      Reagan, Ronald
# 3   1988  Bush, George H. W.
# 4   1992       Clinton, Bill
# 5   1996       Clinton, Bill
# 6   2000     Bush, George W.
# 7   2004     Bush, George W.
# 8   2008    Obama, Barack H.
# 9   2012    Obama, Barack H.
# 10  2016    Trump, Donald J.

# %%
winner_states = pd.merge(states_DR, winnerDF, how='outer', on='year')
winner_states.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-133-edd44b9c0ca1> in <module>
# ----> 1 winner_states = pd.merge(states_DR, winnerDF, how='outer', on='year')
#       2 winner_states.head()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/reshape/merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      71     validate=None,
#      72 ) -> "DataFrame":
# ---> 73     op = _MergeOperation(
#      74         left,
#      75         right,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/reshape/merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     629         # validate the merge keys dtypes. We may need to coerce
#     630         # to avoid incompat dtypes
# ...

# %%
analysis_states = pd.pivot_table(states_DR, values='candidatevotes', index=['year','candidate'], columns='state', fill_value=0, aggfunc=np.sum)
analysis_states
# Out:
# state                   Alabama  Alaska  Arizona  Arkansas  California  \
# year candidate
# 1976 Carter, Jimmy       659170   44058   295602    498604     3742284
#      Ford, Gerald        504070   71555   418642    267903     3882244
# 1980 Carter, Jimmy       636730   41842   246843    398041     3082943
#      Reagan, Ronald      654192   86112   529688    403164     4522994
# 1984 Mondale, Walter     551899   62007   333854    338646     3922519
#      Reagan, Ronald      872849  138377   681416    534774     5467009
# 1988 Bush, George H.W.   815576  119251   702541    466578     5054917
#      Dukakis, Michael    549506   72584   454029    349237     4702233
# 1992 Bush, George H.W.   804283  102000   572086    337324     3630574
#      Clinton, Bill       690080   78294   543050    505823     5121325
# 1996 Clinton, Bill       662165   80380   653288    475171     5119835
#      Dole, Robert        769044  122746   622073    325416     3828381
# ...

# %%
states_DR['percentage'] = states_DR['candidatevotes'] / states_DR['totalvotes']
states_DR
# Out:
# <ipython-input-119-bfadbd94601a>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   states_DR['percentage'] = states_DR['candidatevotes'] / states_DR['totalvotes']
#       year          state state_po  state_fips  state_cen  state_ic  \
# 0     1976        Alabama       AL           1         63        41
# 1     1976        Alabama       AL           1         63        41
# 7     1976         Alaska       AK           2         94        81
# 8     1976         Alaska       AK           2         94        81
# 11    1976        Arizona       AZ           4         86        61
# ...    ...            ...      ...         ...        ...       ...
# 3719  2016  West Virginia       WV          54         55        56
# ...

# %%
JimmyDF1 = states_DR.loc[states_DR['candidate']=='Carter, Jimmy']
JimmyDF = JimmyDF1.loc[JimmyDF1['year']== 1976]
JimmyDF
# Out:
#      year                 state state_po  state_fips  state_cen  state_ic  \
# 0    1976               Alabama       AL           1         63        41
# 8    1976                Alaska       AK           2         94        81
# 12   1976               Arizona       AZ           4         86        61
# 19   1976              Arkansas       AR           5         71        42
# 24   1976            California       CA           6         93        71
# 31   1976              Colorado       CO           8         84        62
# 39   1976           Connecticut       CT           9         16         1
# 43   1976              Delaware       DE          10         51        11
# 50   1976  District of Columbia       DC          11         53        55
# 55   1976               Florida       FL          12         59        43
# 60   1976               Georgia       GA          13         58        44
# 62   1976                Hawaii       HI          15         95        82
# ...

# %%
plt.figure(figsize=(10,8))
plt.bar(JimmyDF['state'], JimmyDF['percentage'])
plt.xticks(rotation=90)
plt.axhline(y=0.50,linewidth=1, color='k')
plt.show()

# %%
plt.figure(figsize=(10,8))
plt.bar(JimmyDF['state'], JimmyDF['candidatevotes'])
plt.xticks(rotation=90)
#plt.axhline(y=0.50,linewidth=1, color='k')
plt.show()

# %%
LDF2 = states_DR.loc[states_DR['state'] == 'Pennsylvania']
LDF2
# Out:
#       year         state state_po  state_fips  state_cen  state_ic  \
# 246   1976  Pennsylvania       PA          42         23        14
# 247   1976  Pennsylvania       PA          42         23        14
# 603   1980  Pennsylvania       PA          42         23        14
# 604   1980  Pennsylvania       PA          42         23        14
# 932   1984  Pennsylvania       PA          42         23        14
# 933   1984  Pennsylvania       PA          42         23        14
# 1231  1988  Pennsylvania       PA          42         23        14
# 1232  1988  Pennsylvania       PA          42         23        14
# 1582  1992  Pennsylvania       PA          42         23        14
# 1583  1992  Pennsylvania       PA          42         23        14
# 1952  1996  Pennsylvania       PA          42         23        14
# 1953  1996  Pennsylvania       PA          42         23        14
# 2314  2000  Pennsylvania       PA          42         23        14
# ...

# %%
#winner = ['Carter, Jimmy', 'Reagan, Ronald', 'Reagan, Ronald', 'Bush, George H.W.', 'Clinton, Bill', 'Clinton, Bill', 'Bush, George W.', 'Bush, George W.', 'Obama, Barack H.', 'Obama, Barack H.','Trump, Donald J.']
JC = states_DR.loc[(states_DR['candidate'] == 'Carter, Jimmy') & (states_DR['year'] == 1976)]
RR = states_DR.loc[(states_DR['candidate'] == 'Reagan, Ronald') & (states_DR['year'] == 1980) | (states_DR['candidate'] == 'Reagan, Ronald') & (states_DR['year'] == 1984)]
GB1 = states_DR.loc[(states_DR['candidate'] == 'Bush, George H.W.') & (states_DR['year'] == 1988)]
BC = states_DR.loc[(states_DR['candidate'] == 'Clinton, Bill') & (states_DR['year'] == 1992) | (states_DR['candidate'] == 'Clinton, Bill') & (states_DR['year'] == 1996)]
GB2 = states_DR.loc[(states_DR['candidate'] == 'Bush, George W.') & (states_DR['year'] == 2000) | (states_DR['candidate'] == 'Bush, George W.') & (states_DR['year'] == 2004)]
BO = states_DR.loc[(states_DR['candidate'] == 'Obama, Barack H.') & (states_DR['year'] == 2008) | (states_DR['candidate'] == 'Obama, Barack H.') & (states_DR['year'] == 2012)]
DT = states_DR.loc[(states_DR['candidate'] == 'Trump, Donald J.') & (states_DR['year'] == 2016)]

test = JC.append(RR)
test2 = test.append(GB1)
test3 = test2.append(BC)
test4 = test3.append(GB2)
test5 = test4.append(BO)
test6 = test5.append(DT)

winners_final = test6.loc[test6['percentage'] > 0.48]

winners_final
# Out:
#       year                 state state_po  state_fips  state_cen  state_ic  \
# 0     1976               Alabama       AL           1         63        41
# 19    1976              Arkansas       AR           5         71        42
# 43    1976              Delaware       DE          10         51        11
# 50    1976  District of Columbia       DC          11         53        55
# 55    1976               Florida       FL          12         59        43
# ...    ...                   ...      ...         ...        ...       ...
# 3676  2016          South Dakota       SD          46         45        37
# 3680  2016             Tennessee       TN          47         62        54
# 3684  2016                 Texas       TX          48         74        49
# 3718  2016         West Virginia       WV          54         55        56
# 3732  2016               Wyoming       WY          56         83        68
#
# ...

# %%
plt.figure(figsize=(10,8))
states_count = winners_final['state'].value_counts()
plt.bar(states_count.index.values, states_count.values)
plt.xticks(rotation=90)
plt.show()

# %%
florida = winners_final.loc[winners_final['state'] == 'Florida']
florida
# Out:
#       year    state state_po  state_fips  state_cen  state_ic        office  \
# 55    1976  Florida       FL          12         59        43  US President
# 397   1980  Florida       FL          12         59        43  US President
# 754   1984  Florida       FL          12         59        43  US President
# 1070  1988  Florida       FL          12         59        43  US President
# 1751  1996  Florida       FL          12         59        43  US President
# 2106  2000  Florida       FL          12         59        43  US President
# 2472  2004  Florida       FL          12         59        43  US President
# 2790  2008  Florida       FL          12         59        43  US President
# 3135  2012  Florida       FL          12         59        43  US President
# 3467  2016  Florida       FL          12         59        43  US President
#
#               candidate       party  writein  candidatevotes  totalvotes  \
# ...

# %%
#states_DR['WL'] = pd.Series([])
#for index, row in states_DR.iterrows(): 
#    if states_DR.loc[index, 'percentage'] > states_DR.loc[str(int(index) - 1), 'percentage']: 
#        states_DR['WL'].append('Winner')
#    elif states_DR['WL'].append('Loser')
#states_DR

# %%
final = states_DR.groupby(['year','state'])['candidatevotes'].max()
finalDF = pd.DataFrame(final)
finalDF
# Out:
#                     candidatevotes
# year state
# 1976 Alabama                659170
#      Alaska                  71555
#      Arizona                418642
#      Arkansas               498604
#      California            3882244
# ...                            ...
# 2016 Virginia              1981473
#      Washington            1742718
#      West Virginia          489371
#      Wisconsin             1405284
#      Wyoming                174419
#
# [561 rows x 1 columns]

# %%
winner = finalDF.merge(states_DR, how='inner', left_on=["candidatevotes"], right_on=["candidatevotes"])
winner
# Out:
#      candidatevotes  year          state state_po  state_fips  state_cen  \
# 0            659170  1976        Alabama       AL           1         63
# 1             71555  1976         Alaska       AK           2         94
# 2            418642  1976        Arizona       AZ           4         86
# 3            498604  1976       Arkansas       AR           5         71
# 4           3882244  1976     California       CA           6         93
# ..              ...   ...            ...      ...         ...        ...
# 556         1981473  2016       Virginia       VA          51         54
# 557         1742718  2016     Washington       WA          53         91
# 558          489371  2016  West Virginia       WV          54         55
# 559         1405284  2016      Wisconsin       WI          55         35
# 560          174419  2016        Wyoming       WY          56         83
#
#      state_ic        office         candidate       party  writein  \
# ...

# %%
winner2 = winner.groupby(['year','state','candidate'])['candidatevotes'].sum()
winner2
# Out:
# year  state          candidate
# 1976  Alabama        Carter, Jimmy        659170
#       Alaska         Ford, Gerald          71555
#       Arizona        Ford, Gerald         418642
#       Arkansas       Carter, Jimmy        498604
#       California     Ford, Gerald        3882244
#                                           ...
# 2016  Virginia       Clinton, Hillary    1981473
#       Washington     Clinton, Hillary    1742718
#       West Virginia  Trump, Donald J.     489371
#       Wisconsin      Trump, Donald J.    1405284
#       Wyoming        Trump, Donald J.     174419
# Name: candidatevotes, Length: 561, dtype: int64
